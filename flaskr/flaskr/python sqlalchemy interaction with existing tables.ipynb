# %%
"""
http://www.blog.pythonlibrary.org/2010/09/10/sqlalchemy-connecting-to-pre-existing-databases/
"""

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy import Column, Integer
from datetime import datetime

# %%
# step 1

# %%
current_id = 6

# %%
engine = create_engine('mysql://root:root@localhost/testdb', echo=False)
#engine = create_engine('mysql://root:root@localhost/testdb', echo=True)
Base = declarative_base(engine)
########################################################################
class Entry(Base):
    """"""
    __tablename__ = 'entries'
    __table_args__ = {'autoload':True}
    id = Column(Integer, primary_key=True)
    
    def my_print(self):
        print self.id
        print self.title
        print self.text

def loadSession():
    """"""
    metadata = Base.metadata
    Session = sessionmaker(bind=engine)
    session = Session()
    return session


if __name__ == "__main__":
    session = loadSession()
    
    # insert
    entry = Entry()
    entry.id = current_id
    current_id += 1
    entry.title = 'title2'
    entry.text = 'text2'
    print entry.id
    print entry.title
    print entry.text
    print 'here'
    session.add(entry)
    session.commit()
    
    res = session.query(Entry).all()
    for rec in res:
        if rec is not None:
            rec.my_print()
    
    print '**************query'
    # query
    res = session.query(Entry).filter_by(title='title2')
    for rec in res:
        rec.my_print()
        
    print '**************delete'
    print session.query(Entry).filter_by(title='title2').count()
    res[-1].my_print()
    session.delete(res[-1])
    print session.query(Entry).filter_by(title='title2').count()
    
    print '**************update'
    res[-2].text = "modified"
    session.commit()
    
    ##############
    res = session.query(Entry).all()
    for rec in res:
        if rec is not None:
            rec.my_print()
# Out:
# 16
# title2
# text2
# here
# 1
# 1
# 2
# 11
# title2
# text2
# 10
# title2
# text2
# 9
# title2
# text2
# 2
# title2
# text2
# 3
# title2
# text2
# 4
# title2
# text2
# 5
# title2
# text2
# 6
# title2
# text2
# 7
# title2
# text2
# 8
# title2
# text2
# 12
# title2
# text2
# 13
# title2
# text2
# 16
# title2
# text2
# **************query
# 11
# title2
# text2
# 10
# title2
# text2
# 9
# title2
# text2
# 2
# title2
# text2
# 3
# title2
# text2
# 4
# title2
# text2
# 5
# title2
# text2
# 6
# title2
# text2
# 7
# title2
# text2
# 8
# title2
# text2
# 12
# title2
# text2
# 13
# title2
# text2
# 16
# title2
# text2
# **************delete
# 18
# 16
# title2
# text2
# 17
# **************update
# 1
# 1
# 2
# 11
# title2
# text2
# 10
# title2
# text2
# 9
# title2
# text2
# 2
# title2
# text2
# 3
# title2
# text2
# 4
# title2
# text2
# 5
# title2
# text2
# 6
# title2
# text2
# 7
# title2
# text2
# 8
# title2
# text2
# 12
# title2
# modified
# 13
# title2
# text2

# %%
current_ue_id = 65000

# %%
dir(OT_User)
# Out:
# ['UE_Faccount',
#  'UE_ID',
#  'UE_accName',
#  'UE_account',
#  'UE_actiCode',
#  'UE_activeTime',
#  'UE_answer',
#  'UE_answer2',
#  'UE_answer3',
#  'UE_check',
#  'UE_drpd',
#  'UE_endtime',
#  'UE_img',
#  'UE_info',
#  'UE_integral',
#  'UE_lastIP',
#  'UE_lastTime',
#  'UE_ldx',
#  'UE_level',
#  'UE_logNum',
#  'UE_mailCheck',
#  'UE_money',
#  'UE_note',
#  'UE_nottask',
#  'UE_nowIP',
#  'UE_nowTime',
#  'UE_password',
#  'UE_phone',
#  'UE_qq',
#  'UE_question',
#  'UE_question2',
#  'UE_question3',
#  'UE_regIP',
#  'UE_regTime',
#  'UE_secpwd',
#  'UE_sfz',
#  'UE_starttime',
#  'UE_status',
#  'UE_stop',
#  'UE_sum',
#  'UE_theme',
#  'UE_toActive',
#  'UE_truename',
#  'UE_verMail',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__mapper__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
# ...

# %%
dir(session)
# Out:
# ['_Session__binds',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_bind',
#  '_after_attach',
#  '_autoflush',
#  '_before_attach',
#  '_bulk_save_mappings',
#  '_close_impl',
#  '_conditional_expire',
#  '_connection_for_bind',
#  '_contains_state',
#  '_delete_impl',
#  '_deleted',
#  '_dirty_states',
#  '_enable_transaction_accounting',
#  '_expire_state',
#  '_expunge_states',
#  '_flush',
#  '_flush_warning',
#  '_flushing',
#  '_identity_cls',
#  '_is_clean',
#  '_merge',
#  '_new',
#  '_query_cls',
#  '_register_altered',
#  '_register_newly_persistent',
#  '_remove_newly_deleted',
#  '_save_impl',
#  '_save_or_update_impl',
#  '_save_or_update_state',
#  '_update_impl',
# ...

# %%
# step 2

engine = create_engine('mysql://root:root@localhost/happykimi?charset=gbk', echo=False)
#engine = create_engine('mysql://root:root@localhost/testdb', echo=True)
Base = declarative_base(engine)
########################################################################
class OT_User(Base):
    """"""
    __tablename__ = 'ot_user'
    __table_args__ = {'autoload':True}
    

def loadSession():
    """"""
    metadata = Base.metadata
    Session = sessionmaker(bind=engine)
    session = Session()
    return session


if __name__ == "__main__":
    session = loadSession()
    
    
    UE_account = 'abcdefg'
    UE_password = 'password'
    UE_truename = u'true name中'
    UE_accName = 'from_who'
    
    #UE_accName = 
    
    ############################################
    # insert
    entry = OT_User()
    #entry.ue_id = current_ue_id
    #current_ue_id += 1
    
    # populate fields with information supplied by users
    entry.UE_account = UE_account
    entry.UE_password = UE_password
    entry.UE_truename = UE_truename
    entry.UE_accName = UE_accName
    
    # populate other fields with not-null constraint
    entry.jihuouser = 'None'
    entry.tx_leiji = 0
    entry.UE_verMail = 'None'
    entry.zcr = UE_account
    entry.UE_regTime = datetime.now()
    
    session.add(entry)
    session.commit()
    
    #res = session.query(OT_User).all()
    #for rec in res:
    #    if rec is not None:
    #        rec.my_print()
""" 
    print '**************query'
    # query
    res = session.query(Entry).filter_by(title='title2')
    for rec in res:
        rec.my_print()
        
    print '**************delete'
    print session.query(Entry).filter_by(title='title2').count()
    res[-1].my_print()
    session.delete(res[-1])
    print session.query(Entry).filter_by(title='title2').count()
    
    print '**************update'
    res[-2].text = "modified"
    session.commit()
    
    ##############
    res = session.query(Entry).all()
    for rec in res:
        if rec is not None:
            rec.my_print()
"""
# Out:
# ' \n    print \'**************query\'\n    # query\n    res = session.query(Entry).filter_by(title=\'title2\')\n    for rec in res:\n        rec.my_print()\n        \n    print \'**************delete\'\n    print session.query(Entry).filter_by(title=\'title2\').count()\n    res[-1].my_print()\n    session.delete(res[-1])\n    print session.query(Entry).filter_by(title=\'title2\').count()\n    \n    print \'**************update\'\n    res[-2].text = "modified"\n    session.commit()\n    \n    ##############\n    res = session.query(Entry).all()\n    for rec in res:\n        if rec is not None:\n            rec.my_print()\n'
